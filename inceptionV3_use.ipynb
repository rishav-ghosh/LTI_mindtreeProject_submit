# %%
from torchvision import datasets, transforms, models
from torch.utils.data import random_split, DataLoader
import os
import torch
import torch.nn as nn
import torch.optim as optim

# %%
DATA_DIR = "/Users/rishavghosh/Desktop/python/Oasis_dataset"

# %%
weights = models.Inception_V3_Weights.DEFAULT
model = models.inception_v3(weights=weights, aux_logits=True)
transform = weights.transforms()

# %%
full_dataset = datasets.ImageFolder(DATA_DIR, transform=transform)
print("Classes:", full_dataset.classes)
# Out:
# Classes: ['Mild Dementia', 'Moderate Dementia', 'Non Demented', 'Very mild Dementia']

# %%
train_size = int(0.8 * len(full_dataset))
test_size = len(full_dataset) - train_size

train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size])

print("Train size:", len(train_dataset))
print("Test size:", len(test_dataset))
# Out:
# Train size: 96336
# Test size: 24085

# %%
from torch.utils.data import WeightedRandomSampler
import numpy as np
import torch

# Extract labels from train dataset
train_targets = [full_dataset.samples[i][1] for i in train_dataset.indices]
class_counts = np.bincount(train_targets)

print("Train class counts:", dict(zip(full_dataset.classes, class_counts)))

# Compute class weights
class_weights = 1. / torch.tensor(class_counts, dtype=torch.float)
sample_weights = [class_weights[label] for label in train_targets]

# Sampler for balanced training
train_sampler = WeightedRandomSampler(weights=sample_weights,
                                      num_samples=len(sample_weights),
                                      replacement=True)
# Out:
# Train class counts: {'Mild Dementia': 11191, 'Moderate Dementia': 5503, 'Non Demented': 61425, 'Very mild Dementia': 18217}

# %%
# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, sampler=train_sampler)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
DEVICE = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

# %%
model.fc = nn.Linear(model.fc.in_features, 4)
if model.AuxLogits is not None:
    model.AuxLogits.fc = nn.Linear(model.AuxLogits.fc.in_features, 4)

model = model.to(DEVICE)
print("Model device:", next(model.parameters()).device)
# Out:
# Model device: mps:0

# %%
criterion = nn.CrossEntropyLoss()

# %%
from torchinfo import summary
summary(model = model,
        input_size = (32, 3, 224, 224),
        col_names = ["input_size", "output_size", "num_params", "trainable"],
        col_width = 20,
        row_settings = ["var_names"]
       )
# Out:
# ========================================================================================================================
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ========================================================================================================================
# Inception3 (Inception3)                  [32, 3, 224, 224]    [32, 4]              2,560,772            True
# ├─BasicConv2d (Conv2d_1a_3x3)            [32, 3, 224, 224]    [32, 32, 111, 111]   --                   True
# │    └─Conv2d (conv)                     [32, 3, 224, 224]    [32, 32, 111, 111]   864                  True
# │    └─BatchNorm2d (bn)                  [32, 32, 111, 111]   [32, 32, 111, 111]   64                   True
# ├─BasicConv2d (Conv2d_2a_3x3)            [32, 32, 111, 111]   [32, 32, 109, 109]   --                   True
# │    └─Conv2d (conv)                     [32, 32, 111, 111]   [32, 32, 109, 109]   9,216                True
# │    └─BatchNorm2d (bn)                  [32, 32, 109, 109]   [32, 32, 109, 109]   64                   True
# ├─BasicConv2d (Conv2d_2b_3x3)            [32, 32, 109, 109]   [32, 64, 109, 109]   --                   True
# │    └─Conv2d (conv)                     [32, 32, 109, 109]   [32, 64, 109, 109]   18,432               True
# │    └─BatchNorm2d (bn)                  [32, 64, 109, 109]   [32, 64, 109, 109]   128                  True
# ├─MaxPool2d (maxpool1)                   [32, 64, 109, 109]   [32, 64, 54, 54]     --                   --
# ├─BasicConv2d (Conv2d_3b_1x1)            [32, 64, 54, 54]     [32, 80, 54, 54]     --                   True
# │    └─Conv2d (conv)                     [32, 64, 54, 54]     [32, 80, 54, 54]     5,120                True
# │    └─BatchNorm2d (bn)                  [32, 80, 54, 54]     [32, 80, 54, 54]     160                  True
# ├─BasicConv2d (Conv2d_4a_3x3)            [32, 80, 54, 54]     [32, 192, 52, 52]    --                   True
# │    └─Conv2d (conv)                     [32, 80, 54, 54]     [32, 192, 52, 52]    138,240              True
# │    └─BatchNorm2d (bn)                  [32, 192, 52, 52]    [32, 192, 52, 52]    384                  True
# ├─MaxPool2d (maxpool2)                   [32, 192, 52, 52]    [32, 192, 25, 25]    --                   --
# ├─InceptionA (Mixed_5b)                  [32, 192, 25, 25]    [32, 256, 25, 25]    --                   True
# │    └─BasicConv2d (branch1x1)           [32, 192, 25, 25]    [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 192, 25, 25]    [32, 64, 25, 25]     12,288               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# │    └─BasicConv2d (branch5x5_1)         [32, 192, 25, 25]    [32, 48, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 192, 25, 25]    [32, 48, 25, 25]     9,216                True
# │    │    └─BatchNorm2d (bn)             [32, 48, 25, 25]     [32, 48, 25, 25]     96                   True
# │    └─BasicConv2d (branch5x5_2)         [32, 48, 25, 25]     [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 48, 25, 25]     [32, 64, 25, 25]     76,800               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# │    └─BasicConv2d (branch3x3dbl_1)      [32, 192, 25, 25]    [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 192, 25, 25]    [32, 64, 25, 25]     12,288               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# │    └─BasicConv2d (branch3x3dbl_2)      [32, 64, 25, 25]     [32, 96, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 64, 25, 25]     [32, 96, 25, 25]     55,296               True
# │    │    └─BatchNorm2d (bn)             [32, 96, 25, 25]     [32, 96, 25, 25]     192                  True
# │    └─BasicConv2d (branch3x3dbl_3)      [32, 96, 25, 25]     [32, 96, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 96, 25, 25]     [32, 96, 25, 25]     82,944               True
# │    │    └─BatchNorm2d (bn)             [32, 96, 25, 25]     [32, 96, 25, 25]     192                  True
# │    └─BasicConv2d (branch_pool)         [32, 192, 25, 25]    [32, 32, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 192, 25, 25]    [32, 32, 25, 25]     6,144                True
# │    │    └─BatchNorm2d (bn)             [32, 32, 25, 25]     [32, 32, 25, 25]     64                   True
# ├─InceptionA (Mixed_5c)                  [32, 256, 25, 25]    [32, 288, 25, 25]    --                   True
# │    └─BasicConv2d (branch1x1)           [32, 256, 25, 25]    [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 256, 25, 25]    [32, 64, 25, 25]     16,384               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# │    └─BasicConv2d (branch5x5_1)         [32, 256, 25, 25]    [32, 48, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 256, 25, 25]    [32, 48, 25, 25]     12,288               True
# │    │    └─BatchNorm2d (bn)             [32, 48, 25, 25]     [32, 48, 25, 25]     96                   True
# │    └─BasicConv2d (branch5x5_2)         [32, 48, 25, 25]     [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 48, 25, 25]     [32, 64, 25, 25]     76,800               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# │    └─BasicConv2d (branch3x3dbl_1)      [32, 256, 25, 25]    [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 256, 25, 25]    [32, 64, 25, 25]     16,384               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# │    └─BasicConv2d (branch3x3dbl_2)      [32, 64, 25, 25]     [32, 96, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 64, 25, 25]     [32, 96, 25, 25]     55,296               True
# │    │    └─BatchNorm2d (bn)             [32, 96, 25, 25]     [32, 96, 25, 25]     192                  True
# │    └─BasicConv2d (branch3x3dbl_3)      [32, 96, 25, 25]     [32, 96, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 96, 25, 25]     [32, 96, 25, 25]     82,944               True
# │    │    └─BatchNorm2d (bn)             [32, 96, 25, 25]     [32, 96, 25, 25]     192                  True
# │    └─BasicConv2d (branch_pool)         [32, 256, 25, 25]    [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 256, 25, 25]    [32, 64, 25, 25]     16,384               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# ├─InceptionA (Mixed_5d)                  [32, 288, 25, 25]    [32, 288, 25, 25]    --                   True
# │    └─BasicConv2d (branch1x1)           [32, 288, 25, 25]    [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 288, 25, 25]    [32, 64, 25, 25]     18,432               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# │    └─BasicConv2d (branch5x5_1)         [32, 288, 25, 25]    [32, 48, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 288, 25, 25]    [32, 48, 25, 25]     13,824               True
# │    │    └─BatchNorm2d (bn)             [32, 48, 25, 25]     [32, 48, 25, 25]     96                   True
# │    └─BasicConv2d (branch5x5_2)         [32, 48, 25, 25]     [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 48, 25, 25]     [32, 64, 25, 25]     76,800               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# │    └─BasicConv2d (branch3x3dbl_1)      [32, 288, 25, 25]    [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 288, 25, 25]    [32, 64, 25, 25]     18,432               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# │    └─BasicConv2d (branch3x3dbl_2)      [32, 64, 25, 25]     [32, 96, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 64, 25, 25]     [32, 96, 25, 25]     55,296               True
# │    │    └─BatchNorm2d (bn)             [32, 96, 25, 25]     [32, 96, 25, 25]     192                  True
# │    └─BasicConv2d (branch3x3dbl_3)      [32, 96, 25, 25]     [32, 96, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 96, 25, 25]     [32, 96, 25, 25]     82,944               True
# │    │    └─BatchNorm2d (bn)             [32, 96, 25, 25]     [32, 96, 25, 25]     192                  True
# │    └─BasicConv2d (branch_pool)         [32, 288, 25, 25]    [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 288, 25, 25]    [32, 64, 25, 25]     18,432               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# ├─InceptionB (Mixed_6a)                  [32, 288, 25, 25]    [32, 768, 12, 12]    --                   True
# │    └─BasicConv2d (branch3x3)           [32, 288, 25, 25]    [32, 384, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 288, 25, 25]    [32, 384, 12, 12]    995,328              True
# │    │    └─BatchNorm2d (bn)             [32, 384, 12, 12]    [32, 384, 12, 12]    768                  True
# │    └─BasicConv2d (branch3x3dbl_1)      [32, 288, 25, 25]    [32, 64, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 288, 25, 25]    [32, 64, 25, 25]     18,432               True
# │    │    └─BatchNorm2d (bn)             [32, 64, 25, 25]     [32, 64, 25, 25]     128                  True
# │    └─BasicConv2d (branch3x3dbl_2)      [32, 64, 25, 25]     [32, 96, 25, 25]     --                   True
# │    │    └─Conv2d (conv)                [32, 64, 25, 25]     [32, 96, 25, 25]     55,296               True
# │    │    └─BatchNorm2d (bn)             [32, 96, 25, 25]     [32, 96, 25, 25]     192                  True
# │    └─BasicConv2d (branch3x3dbl_3)      [32, 96, 25, 25]     [32, 96, 12, 12]     --                   True
# │    │    └─Conv2d (conv)                [32, 96, 25, 25]     [32, 96, 12, 12]     82,944               True
# │    │    └─BatchNorm2d (bn)             [32, 96, 12, 12]     [32, 96, 12, 12]     192                  True
# ├─InceptionC (Mixed_6b)                  [32, 768, 12, 12]    [32, 768, 12, 12]    --                   True
# │    └─BasicConv2d (branch1x1)           [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7_1)         [32, 768, 12, 12]    [32, 128, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 128, 12, 12]    98,304               True
# │    │    └─BatchNorm2d (bn)             [32, 128, 12, 12]    [32, 128, 12, 12]    256                  True
# │    └─BasicConv2d (branch7x7_2)         [32, 128, 12, 12]    [32, 128, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 128, 12, 12]    [32, 128, 12, 12]    114,688              True
# │    │    └─BatchNorm2d (bn)             [32, 128, 12, 12]    [32, 128, 12, 12]    256                  True
# │    └─BasicConv2d (branch7x7_3)         [32, 128, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 128, 12, 12]    [32, 192, 12, 12]    172,032              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7dbl_1)      [32, 768, 12, 12]    [32, 128, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 128, 12, 12]    98,304               True
# │    │    └─BatchNorm2d (bn)             [32, 128, 12, 12]    [32, 128, 12, 12]    256                  True
# │    └─BasicConv2d (branch7x7dbl_2)      [32, 128, 12, 12]    [32, 128, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 128, 12, 12]    [32, 128, 12, 12]    114,688              True
# │    │    └─BatchNorm2d (bn)             [32, 128, 12, 12]    [32, 128, 12, 12]    256                  True
# │    └─BasicConv2d (branch7x7dbl_3)      [32, 128, 12, 12]    [32, 128, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 128, 12, 12]    [32, 128, 12, 12]    114,688              True
# │    │    └─BatchNorm2d (bn)             [32, 128, 12, 12]    [32, 128, 12, 12]    256                  True
# │    └─BasicConv2d (branch7x7dbl_4)      [32, 128, 12, 12]    [32, 128, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 128, 12, 12]    [32, 128, 12, 12]    114,688              True
# │    │    └─BatchNorm2d (bn)             [32, 128, 12, 12]    [32, 128, 12, 12]    256                  True
# │    └─BasicConv2d (branch7x7dbl_5)      [32, 128, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 128, 12, 12]    [32, 192, 12, 12]    172,032              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch_pool)         [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# ├─InceptionC (Mixed_6c)                  [32, 768, 12, 12]    [32, 768, 12, 12]    --                   True
# │    └─BasicConv2d (branch1x1)           [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7_1)         [32, 768, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 160, 12, 12]    122,880              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7_2)         [32, 160, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 160, 12, 12]    179,200              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7_3)         [32, 160, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 192, 12, 12]    215,040              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7dbl_1)      [32, 768, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 160, 12, 12]    122,880              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7dbl_2)      [32, 160, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 160, 12, 12]    179,200              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7dbl_3)      [32, 160, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 160, 12, 12]    179,200              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7dbl_4)      [32, 160, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 160, 12, 12]    179,200              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7dbl_5)      [32, 160, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 192, 12, 12]    215,040              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch_pool)         [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# ├─InceptionC (Mixed_6d)                  [32, 768, 12, 12]    [32, 768, 12, 12]    --                   True
# │    └─BasicConv2d (branch1x1)           [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7_1)         [32, 768, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 160, 12, 12]    122,880              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7_2)         [32, 160, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 160, 12, 12]    179,200              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7_3)         [32, 160, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 192, 12, 12]    215,040              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7dbl_1)      [32, 768, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 160, 12, 12]    122,880              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7dbl_2)      [32, 160, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 160, 12, 12]    179,200              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7dbl_3)      [32, 160, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 160, 12, 12]    179,200              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7dbl_4)      [32, 160, 12, 12]    [32, 160, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 160, 12, 12]    179,200              True
# │    │    └─BatchNorm2d (bn)             [32, 160, 12, 12]    [32, 160, 12, 12]    320                  True
# │    └─BasicConv2d (branch7x7dbl_5)      [32, 160, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 160, 12, 12]    [32, 192, 12, 12]    215,040              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch_pool)         [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# ├─InceptionC (Mixed_6e)                  [32, 768, 12, 12]    [32, 768, 12, 12]    --                   True
# │    └─BasicConv2d (branch1x1)           [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7_1)         [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7_2)         [32, 192, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 192, 12, 12]    [32, 192, 12, 12]    258,048              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7_3)         [32, 192, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 192, 12, 12]    [32, 192, 12, 12]    258,048              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7dbl_1)      [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7dbl_2)      [32, 192, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 192, 12, 12]    [32, 192, 12, 12]    258,048              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7dbl_3)      [32, 192, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 192, 12, 12]    [32, 192, 12, 12]    258,048              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7dbl_4)      [32, 192, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 192, 12, 12]    [32, 192, 12, 12]    258,048              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7dbl_5)      [32, 192, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 192, 12, 12]    [32, 192, 12, 12]    258,048              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch_pool)         [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# ├─InceptionD (Mixed_7a)                  [32, 768, 12, 12]    [32, 1280, 5, 5]     --                   True
# │    └─BasicConv2d (branch3x3_1)         [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch3x3_2)         [32, 192, 12, 12]    [32, 320, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 192, 12, 12]    [32, 320, 5, 5]      552,960              True
# │    │    └─BatchNorm2d (bn)             [32, 320, 5, 5]      [32, 320, 5, 5]      640                  True
# │    └─BasicConv2d (branch7x7x3_1)       [32, 768, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 768, 12, 12]    [32, 192, 12, 12]    147,456              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7x3_2)       [32, 192, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 192, 12, 12]    [32, 192, 12, 12]    258,048              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7x3_3)       [32, 192, 12, 12]    [32, 192, 12, 12]    --                   True
# │    │    └─Conv2d (conv)                [32, 192, 12, 12]    [32, 192, 12, 12]    258,048              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 12, 12]    [32, 192, 12, 12]    384                  True
# │    └─BasicConv2d (branch7x7x3_4)       [32, 192, 12, 12]    [32, 192, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 192, 12, 12]    [32, 192, 5, 5]      331,776              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 5, 5]      [32, 192, 5, 5]      384                  True
# ├─InceptionE (Mixed_7b)                  [32, 1280, 5, 5]     [32, 2048, 5, 5]     --                   True
# │    └─BasicConv2d (branch1x1)           [32, 1280, 5, 5]     [32, 320, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 1280, 5, 5]     [32, 320, 5, 5]      409,600              True
# │    │    └─BatchNorm2d (bn)             [32, 320, 5, 5]      [32, 320, 5, 5]      640                  True
# │    └─BasicConv2d (branch3x3_1)         [32, 1280, 5, 5]     [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 1280, 5, 5]     [32, 384, 5, 5]      491,520              True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch3x3_2a)        [32, 384, 5, 5]      [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 384, 5, 5]      [32, 384, 5, 5]      442,368              True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch3x3_2b)        [32, 384, 5, 5]      [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 384, 5, 5]      [32, 384, 5, 5]      442,368              True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch3x3dbl_1)      [32, 1280, 5, 5]     [32, 448, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 1280, 5, 5]     [32, 448, 5, 5]      573,440              True
# │    │    └─BatchNorm2d (bn)             [32, 448, 5, 5]      [32, 448, 5, 5]      896                  True
# │    └─BasicConv2d (branch3x3dbl_2)      [32, 448, 5, 5]      [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 448, 5, 5]      [32, 384, 5, 5]      1,548,288            True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch3x3dbl_3a)     [32, 384, 5, 5]      [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 384, 5, 5]      [32, 384, 5, 5]      442,368              True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch3x3dbl_3b)     [32, 384, 5, 5]      [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 384, 5, 5]      [32, 384, 5, 5]      442,368              True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch_pool)         [32, 1280, 5, 5]     [32, 192, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 1280, 5, 5]     [32, 192, 5, 5]      245,760              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 5, 5]      [32, 192, 5, 5]      384                  True
# ├─InceptionE (Mixed_7c)                  [32, 2048, 5, 5]     [32, 2048, 5, 5]     --                   True
# │    └─BasicConv2d (branch1x1)           [32, 2048, 5, 5]     [32, 320, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 2048, 5, 5]     [32, 320, 5, 5]      655,360              True
# │    │    └─BatchNorm2d (bn)             [32, 320, 5, 5]      [32, 320, 5, 5]      640                  True
# │    └─BasicConv2d (branch3x3_1)         [32, 2048, 5, 5]     [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 2048, 5, 5]     [32, 384, 5, 5]      786,432              True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch3x3_2a)        [32, 384, 5, 5]      [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 384, 5, 5]      [32, 384, 5, 5]      442,368              True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch3x3_2b)        [32, 384, 5, 5]      [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 384, 5, 5]      [32, 384, 5, 5]      442,368              True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch3x3dbl_1)      [32, 2048, 5, 5]     [32, 448, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 2048, 5, 5]     [32, 448, 5, 5]      917,504              True
# │    │    └─BatchNorm2d (bn)             [32, 448, 5, 5]      [32, 448, 5, 5]      896                  True
# │    └─BasicConv2d (branch3x3dbl_2)      [32, 448, 5, 5]      [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 448, 5, 5]      [32, 384, 5, 5]      1,548,288            True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch3x3dbl_3a)     [32, 384, 5, 5]      [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 384, 5, 5]      [32, 384, 5, 5]      442,368              True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch3x3dbl_3b)     [32, 384, 5, 5]      [32, 384, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 384, 5, 5]      [32, 384, 5, 5]      442,368              True
# │    │    └─BatchNorm2d (bn)             [32, 384, 5, 5]      [32, 384, 5, 5]      768                  True
# │    └─BasicConv2d (branch_pool)         [32, 2048, 5, 5]     [32, 192, 5, 5]      --                   True
# │    │    └─Conv2d (conv)                [32, 2048, 5, 5]     [32, 192, 5, 5]      393,216              True
# │    │    └─BatchNorm2d (bn)             [32, 192, 5, 5]      [32, 192, 5, 5]      384                  True
# ├─AdaptiveAvgPool2d (avgpool)            [32, 2048, 5, 5]     [32, 2048, 1, 1]     --                   --
# ├─Dropout (dropout)                      [32, 2048, 1, 1]     [32, 2048, 1, 1]     --                   --
# ├─Linear (fc)                            [32, 2048]           [32, 4]              8,196                True
# ========================================================================================================================
# Total params: 24,354,536
# Trainable params: 24,354,536
# Non-trainable params: 0
# Total mult-adds (G): 90.75
# ========================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 2379.95
# Params size (MB): 87.18
# Estimated Total Size (MB): 2486.39
# ========================================================================================================================

# %%
def train_one_epoch(loader, optimizer):
    model.train()
    total, correct, loss_sum = 0, 0, 0.0
    for x, y in loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad(set_to_none=True)
        out = model(x)
        if hasattr(out, "logits"):  # InceptionOutputs
            main_logits, aux_logits = out.logits, out.aux_logits
            loss = criterion(main_logits, y)
            if aux_logits is not None:
                loss += 0.4 * criterion(aux_logits, y)
            preds = main_logits.argmax(1)
        else:  # Other models
            loss = criterion(out, y)
            preds = out.argmax(1)
        loss.backward()
        optimizer.step()
        loss_sum += loss.item() * x.size(0)
        correct += (preds == y).sum().item()
        total += y.size(0)
    return loss_sum / total, correct / total

@torch.no_grad()
def evaluate(loader):
    model.eval()
    total, correct, loss_sum = 0, 0, 0.0
    for x, y in loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)
        logits = out.logits if hasattr(out, "logits") else out
        loss = criterion(logits, y)
        preds = logits.argmax(1)
        loss_sum += loss.item() * x.size(0)
        correct += (preds == y).sum().item()
        total += y.size(0)
    return loss_sum / total, correct / total

# %%
# --------------------------
# Phase 1: Head-only training
# --------------------------
for p in model.parameters():
    p.requires_grad = False
for p in model.fc.parameters():
    p.requires_grad = True
if model.AuxLogits is not None:
    for p in model.AuxLogits.parameters():
        p.requires_grad = True

# %%
model = model.to(DEVICE)

# %%
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-3)

# %%
import time
for epoch in range(1, 6):
    t0 = time.time()
    tr_loss, tr_acc = train_one_epoch(train_loader, optimizer)
    val_loss, val_acc = evaluate(test_loader)
    dt = (time.time() - t0) / 60
    print(f"Epoch {epoch:02d} | {dt:.1f} min  "
          f"train {tr_loss:.4f}/{tr_acc*100:.2f}%  "
          f"val {val_loss:.4f}/{val_acc*100:.2f}%")
# Out:
# Epoch 01 | 45.6 min  train 1.1466/57.16%  val 0.9099/61.93%
# Epoch 02 | 38.6 min  train 1.0481/58.42%  val 0.7798/68.31%
# Epoch 03 | 52.2 min  train 1.0225/58.46%  val 0.8468/66.16%
# Epoch 04 | 38.2 min  train 1.0138/58.38%  val 0.8763/64.36%
# Epoch 05 | 39.0 min  train 1.0094/58.23%  val 0.7882/68.01%

# %%
torch.save(model.state_dict(), 'inceptionV3_alzheimers_extraData.pth')
